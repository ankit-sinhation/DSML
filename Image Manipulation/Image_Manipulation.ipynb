# %% [markdown]
# # Image Manipulation using NumPy
# ### (3-D Array Concepts)

# %%
import numpy as np

# %%
#downloading 2 images for the modifications.

# !gdown 1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1o-8yqdTM7cfz_mAaNCi2nH0urFu7pcqI
# To: c:\Users\ankit\anaconda3\codes\Modules\Image Manipulation\emma_stone.jpeg
#
#   0%|          | 0.00/80.3k [00:00<?, ?B/s]
# 100%|██████████| 80.3k/80.3k [00:00<00:00, 767kB/s]
# 100%|██████████| 80.3k/80.3k [00:00<00:00, 767kB/s]

# %%
# !gdown 17tYTDPBU5hpby9t0kGd7w_-zBsbY7sEd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17tYTDPBU5hpby9t0kGd7w_-zBsbY7sEd
# To: c:\Users\ankit\anaconda3\codes\Modules\Image Manipulation\fruits.png
#
#   0%|          | 0.00/4.71M [00:00<?, ?B/s]
#  11%|█         | 524k/4.71M [00:00<00:03, 1.16MB/s]
#  22%|██▏       | 1.05M/4.71M [00:00<00:02, 1.72MB/s]
#  33%|███▎      | 1.57M/4.71M [00:00<00:01, 1.83MB/s]
#  44%|████▍     | 2.10M/4.71M [00:01<00:01, 2.19MB/s]
#  56%|█████▌    | 2.62M/4.71M [00:01<00:00, 2.71MB/s]
#  78%|███████▊  | 3.67M/4.71M [00:01<00:00, 3.58MB/s]
#  89%|████████▉ | 4.19M/4.71M [00:01<00:00, 3.65MB/s]
# 100%|██████████| 4.71M/4.71M [00:01<00:00, 3.70MB/s]
# 100%|██████████| 4.71M/4.71M [00:01<00:00, 2.82MB/s]

# %%
# !pip install matplotlib 
import matplotlib.pyplot as plt

# %%
img = plt.imread('fruits.png')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         ...,
#         [0.8       , 0.85490197, 0.9098039 ],
#         [0.8       , 0.85490197, 0.9098039 ],
#         [0.8       , 0.85490197, 0.9098039 ]],
#
#        [[0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         ...,
#         [0.8       , 0.85490197, 0.9098039 ],
#         [0.8       , 0.85490197, 0.9098039 ],
#         [0.8       , 0.85490197, 0.9098039 ]],
#
#        [[0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         [0.8784314 , 0.9137255 , 0.972549  ],
#         ...,
#         [0.8039216 , 0.85882354, 0.9137255 ],
#         [0.8039216 , 0.85882354, 0.9137255 ],
#         [0.8039216 , 0.85882354, 0.9137255 ]],
#
#        ...,
#
#        [[0.74509805, 0.79607844, 0.87058824],
# ...

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (1333, 2000, 3)

# %%
img_r = img.copy()

# %%
img_r [: , : , (1,2)] = 0
plt.imshow(img_r)

# %%
img_g = img.copy()

# %%
img_g [: , : , (0,2)] = 0
plt.imshow(img_g)

# %%
img_emma = plt.imread('emma_stone.jpeg')
plt.imshow(img_emma)

# %%
img_emma.shape
# Out:
# (600, 900, 3)

# %%
img_rotated = np.transpose(img_emma , (1,0,2))
plt.imshow(img_rotated)

# %%
img_crop = img_emma[:400 , 200:700 , :]
plt.imshow(img_crop)

# %%
plt.imsave('emma_trim.jpg' , img_crop)
